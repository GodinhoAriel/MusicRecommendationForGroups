# %%
import pprint
import pymongo
from pymongo import MongoClient
from bson.objectid import ObjectId
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import math
import spotipy
import spotipy.util as util

## SETUP
# C:\MongoDB\bin\mongod.exe --dbpath=C:\MongoDB\data\db --directoryperdb
pp = pprint.PrettyPrinter()
client = MongoClient('localhost', 27017)
db = client.server

# %% [raw]
# ## SETUP
#     # Clustering
#         # number of clusters to recommend
#         # number of musics to recommend
#         # min popularity
#     # ContentBased
#         # number of genres to recommend
#         # number of musics to recommend
#     #
# ## TRAINING
#     # Clustering
#     # ContentBased
# ## CANDIDATE GENERATION
#     # Clustering
#     # ContentBased
#     # Maybe add user's libs?
#     # Mayby find suitable music using spotify's recommender and user's top genres?
#     # Unify and remove duplicates
# ## SCORING
#     # Clustering
#     # ContentBased
#     # Unify
# ## RECOMMEND!
#     # Take top x
#     # Generate playlist
# ## PLAY
#     # Run playlist

# %%
import pymongo
from pymongo import MongoClient
from bson.objectid import ObjectId
from sklearn.cluster import KMeans
import math

client = MongoClient('mongodb://musicclustering:o5oF111QxnPaMXmk@clustermdb-shard-00-00-gg5i3.gcp.mongodb.net:27017,clustermdb-shard-00-01-gg5i3.gcp.mongodb.net:27017,clustermdb-shard-00-02-gg5i3.gcp.mongodb.net:27017/test?ssl=true&replicaSet=ClusterMDB-shard-0&authSource=admin&retryWrites=true')
db = client.server

def euclidian_distance(pointA, pointB):
    distance = 0
    for valA, valB in zip(pointA, pointB):
        distance += (valA - valB) ** 2
    
    return math.sqrt(distance)


def sum_distances(centroids, labels, values):
    total_sum = 0
    
    for value, label in zip(values, labels):
        total_sum += euclidian_distance(value, centroids[label]) ** 2        
        
    return total_sum

def k_means(values, k):
    clf = KMeans(n_clusters = k)
    clf.fit(values)

    print('Fit done. k =', k)

    centroids = clf.cluster_centers_
    labels = clf.labels_

    total_distance = sum_distances(centroids, labels, values)
    
    return (centroids, labels, total_distance)

# def standart_deviation(mean, values):
#   sd_vector = []
#   for i in range(len(mean)):
#       d_sum = 0
#       for value in values:
#           d_sum += (mean[i] - value[i]) ** 2
#       sd = math.sqrt(d_sum / (len(values)-1))
#       sd_vector.append(sd)
#   return sd_vector

def generate_recommendation(user, count=100, k=8, min_popularity = 50):
    # Get user tracks
    results = db.tracks.find({'id' : {'$in' : user['tracks_ids']}}, {'_id': 0, 'id': 1, 'features.acousticness' : 1, 'features.danceability' : 1, 'features.energy' : 1, 'features.instrumentalness' : 1, 'features.liveness' : 1, 'features.speechiness' : 1, 'features.valence': 1})
    user_tracks = list(results);

    # extract values and run kmeans
    values = [list(item['features'].values()) for item in user_tracks]  
    (centroids, labels, total_distance) = k_means(values, k)

    # Get all tracks
    results = db.tracks.find({'id' : {'$in' : user['tracks_ids']}, 'popularity' : {"$gte": min_popularity} }, {'_id': 0, 'id': 1, 'features.acousticness' : 1, 'features.danceability' : 1, 'features.energy' : 1, 'features.instrumentalness' : 1, 'features.liveness' : 1, 'features.speechiness' : 1, 'features.valence': 1})
    tracks = [(item['id'], list(item['features'].values())) for item in list(results)]

    # Evaluate tracks
    evaluated_tracks = evaluate_tracks(centroids, labels, tracks)

    return [item[1] for item in evaluated_tracks[0:count]]


def evaluate_tracks(centroids, labels, tracks):
    performance_list = []
    for track in tracks:
        performance = recommendation_performance(track, centroids, labels)
        performance_list.append((performance, track[0]))
    performance_list.sort(reverse=True)
    return performance_list

def recommendation_performance(track, centroids, labels):
    performance = 0
    centroid = centroids[0]
    n_features = len(centroid)
    
    #find closest centroid and biggest centroid size
    lesser_distance = 999
    greatest_count = 0
    cluster_index = 0
    for i in range(len(centroids)):
        c = centroids[i]
        distance = euclidian_distance(c, track[1])
        count = list(labels).count(i)
        if distance < lesser_distance:
            lesser_distance = distance
            centroid = c
            cluster_index = i
        if count > greatest_count:
            greatest_count = count
    
    #ratio of the cluster's respective size in relation to the biggest cluster
    cluster_size_ratio = list(labels).count(cluster_index) / greatest_count
    
    # # Avarage of the cluster's deviations
    # cluster_avg_deviation = 0
    # for val in deviations[cluster_index]:
    #     cluster_avg_deviation += val **2        
    # cluster_avg_deviation = math.sqrt(cluster_avg_deviation) / n_features
    
    return  cluster_size_ratio * (1-lesser_distance)

def setup_user(user, k=8):
    # Get user tracks
    results = db.tracks.find({'id' : {'$in' : user['tracks_ids']}}, {'_id': 0, 'id': 1, 'features.acousticness' : 1, 'features.danceability' : 1, 'features.energy' : 1, 'features.instrumentalness' : 1, 'features.liveness' : 1, 'features.speechiness' : 1, 'features.valence': 1})
    user_tracks = list(results);

    # extract values and run kmeans
    values = [list(item['features'].values()) for item in user_tracks]  
    (centroids, labels, total_distance) = k_means(values, k)
    return (centroids, labels)

# %%
def moderator_generate_playlist(user_ids, pesos, count=100):    
    users = db.users.find({'id' : {'$in': user_ids}})
    #pp.pprint(list(users))
    
    candidate_tracks = []
    centroid_list = []
    label_list = []
    
    for user in users:
        # Clustering
        (centroids, labels) = setup_user(user, k=8)
        centroid_list.append(centroids)
        label_list.append(labels)
        candidate_tracks.extend(generate_recommendation(user, count=100, min_popularity = 50))
        # Content-based
        #candidate_tracks.extend(content_based_recommend(user))
    #print(candidate_tracks)
    
    # Clustering Eval
    i = 0
    evaluations = []
    for user in users:
        evaluated_list = evaluate_tracks(centroid_list[i], label_list[i], candidate_tracks)
        evaluations.append(evaluated_list)
        #pp.pprint(evaluated_list)
        i+=1
    
    pp.pprint(evaluations)
    # Moderator Eval
    final_evaluation = []
    for track_id in candidate_tracks:
        track_eval = 0
        for eva in evaluations:
            filter_result = [item[0] for item in eva if item[1] == track_id]
            if(len(filter_result) > 0):
                track_eval += pesos[0] * filter_result[0][0]
        final_evaluation.append((track_eval, track_id))
    
    # Sorting
    final_evaluation.sort(reverse=True)
    # Results
    #return [item[1] for item in final_evaluation[0:count]]
    return final_evaluation



results = moderator_generate_playlist(
    ['12152580425', '12151527942'],
    [1,1])
pp.pprint(results)
# Out:
# [{'_id': ObjectId('5c18c3213b7750008d64aeba'),
#   'finished_loading': False,
#   'id': '12151527942',
#   'image': {'height': None,
#             'url': 'https://platform-lookaside.fbsbx.com/platform/profilepic/
#                  '1NsmgMBlh1vBOEziDCU4Ac',
#                  '5xlEIMFGXiibSdMZsOqLEl',
#                  '4vezMmAndXw7Jxl9N55Hab',
#                  '3jp7Ryj1sX3riA7NQaVlLd',
#                  '5jvsNqMAz8e3idVrfbMfUA',
#                  '0cPFDJKfL1CRsIirnN3mgW',
#                  '1KqlVt63Q4bl1VdSlymr5C',
#                  '0VhDlpezWuAgOnfOCx2fRv',
#                  '5LOaKdW9D2Gl9neAN94NbR',
#                  '5PZK7nZBsKjSkXDszKrJ1W',
#                  '7oK9VyNzrYvRFo7nQEYkWN',
#                  '4S8iJpjnjUnjErnCyG6pfL',
#                  '5vGEdM7LvbgMypJkILhQ4p',
#                  '3nI0piSOxAik2RCpHGloB7',
#                  '7IHOIqZUUInxjVkko181PB',
#                  '5Wu8be1j6TkIt0lgqhtmvD',
#                  '3g5FrnRdbmDQyWNiDIprts',
#                  '79VHuBNu3VR1QuOlnW3E9t',
#                  '0Z96ZExECrYSQo03nfCak0',
#                  '6RB9YvNyP0RZfCUcMtZELH',
#                  '3SPVZJzf1Hs30rB6yXVf2y',
#                  '0yshYreYZ6tIASQx6QO1Lo',
#                  '6kJmZqhB2Pf2442GOCAohB',
#                  '006pMMCuRo2TFjh8sNGSov',
#                  '2BHfb1qBSA8IzsJUVQvFTZ',
#                  '4TOY0nJD6T0xhTT7l9W9xC',
#                  '2ltHN1EsTlBvfIlC7e0XRL',
#                  '025zQ5QUS3bauhTtYx1ha2',
#                  '2Pr6qNmiOxTdo8B6bs8x8x',
#                  '1cc0kyZrheNxOYPn3VoVEH',
#                  '4RLp0EpcPdMHHoHmYIMWGH',
#                  '1ECean5dVz7mYQ07mdVGKT',
#                  '4uA1DEgqbEAuxDxtJXJCWC',
#                  '5IEd8rLhfOJPHq9PceoW0F',
#                  '5tm7jCfrmhGkXFXEXtz8BL',
#                  '2sLvYnCS3S8klPvZGXGic2',
#                  '7wuQVU5RPvGCXVa9DFrA40',
#                  '2qM94kMAXTinzxlWUUW73Q',
#                  '3pSTUZbp7J5jg2JHChTf21',
#                  '2GAFZG9Z7UGS1iMm4Idrnr',
#                  '2DQOZzt01H5YIC5uV6GHUC',
#                  '4HbbqtgvsHf1pKpxa1ENWs',
#                  '3usVf6rhG6vDjcodeavHde',
#                  '5rjSKhSHGsKP2RJtbRWQkl',
#                  '4fDo7nkzkkhDVockvA1hIp',
#                  '6C5jRZIjka2fbbhdkKdxUj',
#                  '326bWCxEn2UMzIEjhmHewg',
#                  '5uGff7D5vxg14K78KwnTnY',
#                  '3j3vVPmodUy9zg1zb9NAgH',
#                  '3GATWlIrMSwKbJLs7pBQGf',
#                  '7cEzcK6waSwyLmtry1xIxQ',
#                  '4onmWMw3EZLKPC3nyXZvhm',
#                  '0MH0v2UYNWI5qR9DmRoUlJ',
#                  '05ZGYRq34B98uu0NW2BMHh',
#                  '30cbyzf7NQXFMYacWA9YB5',
#                  '4VWbPQUPvLes814r6T11Jz',
#                  '3tRMcxAVPS0YK00YcSc737',
#                  '0pjOjoHMJrerHhiXNRs3GK',
#                  '6YUTL4dYpB9xZO5qExPf05',
#                  '1n108NGnovKSwv2z0J9Vmw',
#                  '4eLSCSELtKxZwXnFbNLXT5',
#                  '5Fli1xRi01bvCjsZvKWro0',
#                  '6a4H76MepL3NQ8jdHmfA6G',
#                  '3wV2NK0Bdz5liE0t0iJIHx',
#                  '3uYzfyifC7J1j1IEjN1xz6',
#                  '4dDvtBzbQqy7iG5Jfr0qif',
#                  '6AVbtprNn18sQcX54K5MTo',
#                  '3qS3kmobYtbPDI66Y3HlpB',
#                  '4ZNVCUq5Fvgeb2auWFwQDB',
#                  '1M0i7gzsHulM28i7dgE32t',
#                  '0xM8eMpK5MC9KJA45AAdjR',
#                  '2qvIr52Y5G2gggJLTZC0IL',
#                  '0OpSYP9Oly3SqmeIgiRnzT',
#                  '4wzt5Rrk3W98pHXAqutuJw',
#                  '2dphvmoLEXdk8hOYxmHlI3',
#                  '5PIbVWsxoBEgH3JjdF5iQK',
#                  '75JFxkI2RXiU7L9VXzMkle',
#                  '5Kayf37CYgsWqgkWMTHZPu',
#                  '1XXAEzRFi0cs0Zh2R42jG1',
#                  '55oSJApfuRnPT4YlYsmqzE',
#                  '18PbKNh8nuvrsq54GpCkoK',
#                  '3pRRYcXy3Z0PsAa8griSoF',
#                  '4yzgjSHWy5E8fKflgwaKQh',
#                  '3QmesrvdbPjwf7i40nht1D',
#                  '4BpndTKEqpLgntffipC53q',
#                  '1ZyBSeyX7ISulW1NARgWFS',
#                  '0DUaFpOFS5H8LbswpbcP2m',
#                  '612VcBshQcy4mpB2utGc3H',
#                  '3JO8ZHz8hF9R4XUd7sGE1N',
#                  '3hoTcwDaUAXXO0bT3sA2ga',
#                  '0l2HaL3nbp9AFJ428p4yaA',
#                  '5UkphDvYcozF86dSasav16',
#                  '2YRsl8s8BAvkmNNHKqxVhN',
#                  '3FJRr8qYvJNrxR9o3m5wF3',
#                  '3m6KkYKdnbffMpGd9Pm9FP',
#                  '4wYYkZvSkkufowykDVMIbN',
#                  '3ehrxAhYms24KLPG8FZe0W']},
#  {'_id': ObjectId('5c1a12cf3b77500015e10d09'),
#   'finished_loading': True,
#   'id': '12152580425',
#   'image': {'height': None,
#             'url': 'https://scontent.xx.fbcdn.net/v/t1.0-1/p200x200/20953766_1551036384918374_7963044392351467383_n.jpg?_nc_cat=108&_nc_ht=scontent.xx&oh=c35b78c527fb68762d8eb62cdf95ea52&oe=5C9B69D1',
#             'width': None},
#   'name': 'Ariel Godinho',
#   'tracks_ids': ['1wLqPjSFDIH59nhQ5Th5XT',
#                  '7f0vVL3xi4i78Rv5Ptn2s1',
#                  '0dMYPDqcI4ca4cjqlmp9mE',
#                  '3eSyMBd7ERw68NVB3jlRmW',
#                  '2sHLWUTiaBPGOIZinpqO4C',
#                  '1mgWnqeUOurHJIyorDtuqF',
#                  '1esX5rtwwssnsEQNQk0HGg',
#                  '57lCa95tmjJ8EYdNTex8Kk',
#                  '7lvZfms8Bh8QnThBmFTD7a',
#                  '7pdG3g13RKtrCmKwnSDeO4',
#                  '0RILico3Gbl5jxSNg3zLrJ',
#                  '7hN5TKSdRb56uytwIpcUES',
#                  '2kWowW0k4oFymhkr7LmvzO',
#                  '4T6qHpA6VSKZL2MDlDOgJB',
#                  '5H6Qw1ZQcJfUUBDVwk5SHt',
#                  '23T5yx8PbwqdssY15XAMvP',
#                  '6kZFIsYCBeuH0f1zGk1UoM',
#                  '6cr6UDpkjEaMQ80OjWqEBQ',
#                  '5MxNLUsfh7uzROypsoO5qe',
#                  '6Azp2KOPFbwoGO97QQRlk9',
#                  '4HpyF7cUsAdvhTV0Bojbk3',
#                  '4tylyIG4Hejckg72SXbdOk',
#                  '6Zx1aP9fb80X9hho26Geha',
#                  '07QuKUTu5O40AibYYPx98I',
#                  '6t1ahr2f1t9iSjjNFwFb4C',
#                  '1UOhKnE2fZJuGdB7ssn9nf',
#                  '2OHQhOiGIYaXqqJVIMpNrF',
#                  '3sbBOn0ifcgoX3MfaTeFKr',
#                  '2E1iBFsm45IcS6Y8WMlZty',
#                  '0HD0eQoUa4BU8Al5nD5nMs',
#                  '2PdAkRZKiwjDzRNWFdXvp6',
#                  '3Vo4wInECJQuz9BIBMOu8i',
#                  '2Imq77E6CEJR5TPUxlJvTY',
#                  '6V933Ab1xEyw7iIDOO2ntl',
#                  '5NZmOhjnDRhqw4uiPQaTEI',
#                  '2ef6K7WCV8khtntJW81S7R',
#                  '1HQoGpPJ8ye2BEavUqdnF9',
#                  '6u0EAxf1OJTLS7CvInuNd7',
#                  '5k38wzpLb15YgncyWdTZE4',
#                  '64ygSCb6X56Uu90GFji1Oo',
#                  '6T8cJz5lAqGer9GUHGyelE',
#                  '3sIMCkwUZbQbWeNOTG3ET4',
#                  '5UEnHoDYpsxlfzWLZIc7LD',
#                  '3twEx52dboO1CqWu5x1i2h',
#                  '0npA0d5jbB01k53LMRccKP',
#                  '6LxlZSTN3NrNl4c88VpB1E',
#                  '1TKTiKp3zbNgrBH2IwSwIx',
#                  '05uGBKRCuePsf43Hfm0JwX',
#                  '2TjdnqlpwOjhijHCwHCP2d',
#                  '7F02x6EKYIQV3VcTaTm7oN',
#                  '2ctvdKmETyOzPb2GiJJT53',
#                  '3TO7bbrUKrOSPGRTB5MeCz',
#                  '0vFOzaXqZHahrZp6enQwQb',
#                  '5HNCy40Ni5BZJFw1TKzRsC',
#                  '4gMgiXfqyzZLMhsksGmbQV',
#                  '6mFkJmJqdDVQ1REhVfGgd1',
#                  '1PH5Es89c1cENU8WVuWwbp',
#                  '4npMbTuxrUA3Wd7edACZ2L',
#                  '2LD2gT7gwAurzdQDQtILds',
#                  '7cMFjxhbXBpOlais7KMF3j',
#                  '098ttCNmncrO4YvqWUNMvn',
#                  '6vuPZX9fWESg5js2JFTQRJ',
#                  '186hvCTyrni4KT9nwIQ7zS',
#                  '1pyTJdbGVBVvKXC3MtemHA',
#                  '15WSNNQZRQDOrzuKYMyrDX',
#                  '1iNeZGJsoC0D7ZyJTdIbDS',
#                  '5bRDSGmwZJsGG7tPN14fDu',
#                  '2FTxc9WUZcKFQtFrT1oOVd',
#                  '4yjlWacI4vXSwtE7Kq7rUH',
#                  '1YAZnUJ415zrzzqkqAGqBv',
#                  '3QGJswb37JtSf5rsacHxCl',
#                  '5yLNO17HNKXD0tjWkZ76PK',
#                  '4PSiPZp8MYMDZzuBhCLgc6',
#                  '2V4bv1fNWfTcyRJKmej6Sj',
#                  '30uJNlHIjfDeE4vr8g9fpf',
#                  '0qeKzbUsW0V4ZWRJrHNiD3',
#                  '0mD19MC6H0OzHvEUADHypU',
#                  '7cKLOenzViwzoHJWciMIrj',
#                  '2pS9wwKRtA3Kb07WzbeiWw',
#                  '7rtUEnmzlULs6kSCmEwgGr',
#                  '6AbVJjzv7thIvmMCuhZrmK',
#                  '2e5Vm6VvdlTzuNcRSikeU6',
#                  '26K4tbF6waeJzo11e3JDo8',
#                  '4hd4x0iaXAQ2pIcyUgHB7h',
#                  '1QQfbfMfyzNZhT5fg3RpuS',
#                  '3SdYnX1212sx5X0N4Lj3Vb',
#                  '3ao5U0ksMLvgSoJqOpsgmv',
#                  '791RIDLITeStIp7YFGQnC0',
#                  '1bdXMstfxFWYSkEFTnJMoN',
#                  '1G391cbiT3v3Cywg8T7DM1',
#                  '3ZOEytgrvLwQaqXreDs2Jx',
#                  '1f2V8U1BiWaC9aJWmpOARe',
#                  '3ezTPbBsazIhjvNb3LNP63',
#                  '5c5a2Ptu8eyIpljhQHjIqk',
#                  '7BHPGtpuuWWsvE7cCaMuEU',
#                  '7vgNGxchhqDQWjKjLPTPro',
#                  '7vxMtIwEn1bUKTqPKEMzJJ',
#                  '6zZw7RPIs3IxDghP4UvWcY',
#                  '0r0U9AcE4LP0QzJQDUUlXP',
#                  '4BjPsq3MXBNo4Qxg40igEr',
#                  '4kkQGhScJDzNIIGavQE9SN',
#                  '6waLZw9qNP36DtHFPeyTz6',
#                  '23JQDwB9UM9uSZZuVKwCEM',
#                  '2DgQLg0xllUwBwAtMsYiNH',
#                  '78Az0Z1vNJgqv9QSB0ULLV',
#                  '2ZSCy3P1QzpJySCWA6NRIU',
#                  '7MQJYm0QPF2Vf0UtzKapSc',
#                  '2rb5MvYT7ZIxbKW5hfcHx8',
#                  '5JZlDZzWPbrYwMHmnOQO3U',
#                  '57AmbM2loMyozAU1kjW308',
#                  '5ac0YTpOaDX9wEYYyGCglL',
#                  '7yYOMPwpV5CsK0cxoAZT6B',
#                  '2srL4DYBekshpbprS6H0mO',
#                  '3ibRxEv4KkcU9e259eyNJA',
#                  '2vKak1euzFLHwzo1iOsz19',
#                  '4vx4kn9JViiFHC5gSuKPpy',
#                  '693iqPOQvhI7PobtR8CC8v',
#                  '6WbADFqMvR8N5u0BvtsWQE',
#                  '7vGuf3Y35N4wmASOKLUVVU',
#                  '0ofbQMrRDsUaVKq2mGLEAb',
#                  '1OmcAT5Y8eg5bUPv9qJT4R',
#                  '0fF0HtZGSXZgGrC6b7Pq4I',
#                  '7uS3slHwc2pm6OfHWUqL2B',
#                  '4bCcolgdC8YsXUiqRgEgRU',
#                  '754w4HeOR2R6Si4UmQB8tv',
#                  '2Z6ZTszw9sHvIhkjpykjV6',
#                  '4nNZ4ra9sJnsdixXELkfW5',
#                  '5VnyRoMMNbBIYiyE4jn5u4',
#                  '7hDc8b7IXETo14hHIHdnhd',
#                  '2fL6P9bUWozes5xaHLddVT',
#                  '1NDxZ7cFAo481dtYWdrUnR',
#                  '3a1lNhkSLSkpJE4MSHpDu9',
#                  '6jA8HL9i4QGzsj6fjoxp8Y',
#                  '1sXUWdKx03aP9Gmzft58rt',
#                  '1louJpMmzEicAn7lzDalPW',
#                  '1x5sYLZiu9r5E43kMlt9f8',
#                  '1F2HXIJrE2Xn81OzT2zZvW',
#                  '4iLqG9SeJSnt0cSPICSjxv',
#                  '72Q0FQQo32KJloivv5xge2',
#                  '07wk7gOL46W63TNxCxwATE',
#                  '2LtDbzTuJTybdPRx5ihGMI',
#                  '6KbJNGFOt922cRSHw8PdPd',
#                  '53968oKecrFxkErocab2Al',
#                  '1AeZGZtgWxgd5ye9h7rzWx',
#                  '2WfaOiMkCvy7F5fcp2zZ8L',
#                  '3LIaJyHeA9lxmskbFaez44',
#                  '75XV0Y9AQ5EjvZZIWb61jA',
#                  '191mdq1JPfMlY3m9ruFcdO',
#                  '0Mh4id8WvrTFOB9RiVitrB',
#                  '3TJk0aoXM0knrOlgd1fnbx',
#                  '1dnXuEuApvuVqQCn0v9McL',
#                  '6ndmKwWqMozN2tcZqzCX4K',
#                  '5wh1I66DNl5jdJkNTBNN6S',
#                  '36AGK6nbzwXZEyoOngaPNz',
#                  '6LIGU1z7M7GTbUxS6vYawX',
#                  '2lBhQDBX4kbNrWQOS5HCk0',
#                  '1coQgkLujv6HkFcToOI7CX',
#                  '24vKziOpfXphE3oNAzPTk7',
#                  '5ipyeQlpSCGkEWNWWfbkfH',
#                  '5uph1dTIcGgCb6GxFmOS1o',
#                  '6LePe9fsXOc3Mb1L2cF61c',
#                  '6lYktNy0nhWLQjo6zvKizF',
#                  '3IuPHUeLhSfuzSQ4AZTAIM',
#                  '1lLUZODZ8c2g1ra1hXNunu',
#                  '5PwCuqzezD4a7mfxMNwk86',
#                  '2pq9pe4fR25v736ZXa8IRn',
#                  '0QUnmV6YpbP6F1ovVQbcy1',
#                  '4vDPWZmY4nDcpGJucryian',
#                  '6agXOyyawuW152l4L0VrDS',
#                  '4BEdYv5U5sCQHIdUkZ4ZPc',
#                  '5NesPUisbN8xl0RyIarG5j',
#                  '5F9Td50J660cg3XgoNFzLN',
#                  '2M7n4GGXHJmPqtJt32ONXT',
#                  '1twBt7aZiy7HWPG025QGuP',
#                  '0EYOdF5FCkgOJJla8DI2Md',
#                  '7dQopLG5o7OtJwxVXW9C35',
#                  '1TJWV70XSJSPhIHXomGIFs',
#                  '211NI9FIN2QTfBfE36X5Jy',
#                  '42mamOOcApbNACFklr0E8v',
#                  '4L90JR2FzHKtHvoWABIoKf',
#                  '6AUyNMc0Na36XmwRpsBSAM',
#                  '4XrutryE5ny1w19lfZPSr2',
#                  '5z01Gx5dldV7Uijgr6sLqh',
#                  '6aLl8i6NEA3nzPWVtjFhGp',
#                  '3R6dPfF2yBO8mHySW1XDAa',
#                  '76gUmNLXGQVOsGhfcshkFP',
#                  '5mCPDVBb16L4XQwDdbRUpz',
#                  '1MJLy6X97ZSCVqFdHjVlz0',
#                  '7ac8sivblLQjsQipO5FZ63',
#                  '7MIzAYEVULbhSwP6vK1zVH',
#                  '2Q2fW2yb1bc2UEfkiLQnnh',
#                  '2BXUyqfXTyGNGJYfOeW61K',
#                  '3Vek6VBsc7NcLQeMTqdUQc',
#                  '2iUjh1ewGITH8KZdZYpqaG',
#                  '5R1kBNvkk4GgqOPTeJ5TlB',
#                  '0SGkqnVQo9KPytSri1H6cF',
#                  '1CnPYaKxTVb4LWOtiGOm0m',
#                  '5hYTyyh2odQKphUbMqc5gN',
#                  '6gpcs5eMhJwax4mIfKDYQk',
#                  '7DoBn08dqKS9MmtZiZChVD',
#                  '3tioB6zOA5LAWAzrWLJs6h',
#                  '6kaGNdHjwnBDCEcYXMx4E7',
#                  '4olmDJKaWL8i4SNJHceZ5Y',
#                  '6VuficDTQ1RrAWvGETPQJE',
#                  '3FO8PIKuriDbQTKHvCuHb0',
#                  '4zG0z77F13gVE51XXlYZs3',
#                  '0bCLok3pkMS2lJtbgPVhph',
#                  '4IzeKSjXW67WLRV5WG7F3A',
#                  '04w0DIF4bfFgnm6yLEtnrh',
#                  '0A2G1FGW3JqWgSiHwJ6xKO',
#                  '3SULDgwQnawVyRNNYTw03e',
#                  '2CVqRq08hwneFVD6N1IP2Q',
#                  '0K1oCudr2sTfkuNaFL1Dyo',
#                  '5oZEWnw1r4l5HEtfS1sjYp',
#                  '5VvDVCUg5PhWQxMcRpRjn4',
#                  '5FuNHXkE6X9dR88IPbceTU',
#                  '3q5gxvfF9KJFUk4YnhkkoT',
#                  '6d2WKJkJIBgPiDp6ComRlz',
#                  '2KGv51jgAz8OTjNPyRryfq',
#                  '3iDY4SzUHPkC3WTXpfxXJG',
#                  '2Gvn46nwyQhUnQiFhlP7WX',
#                  '2GfxgssRHvY1azHtaRqKoK',
#                  '0jIitZeIQRTaZgFQf2WpGK',
#                  '6zCqeUUqLb2CapBmVwAHll',
#                  '0Kr77AosR2k944IhHm8zhH',
#                  '7vLG0D8ouHd4brF5TVJQya',
#                  '4JWvILyOVmhPqXgSSjVB4p',
#                  '0u8aj0c4IxeVSLTUuuq9V5',
#                  '6VRghJeP6I0w1KxkdWFfIh',
#                  '5NNlUMcOEOdoOIwwaWXv0k',
#                  '0KKkJNfGyhkQ5aFogxQAPU',
#                  '15vzANxN8G9wWfwAJLLMCg',
#                  '1dNIEtp7AY3oDAKCGg2XkH',
#                  '4FHw39Ke6pVt5tNKvLr4r3',
#                  '1ulUfMsfRkbWt0xmLYLThG',
#                  '5JSNcb3MwTxkDH4mrYKnHG',
#                  '6m2LNopVJKsvBB9l7Z1rwn',
#                  '257tme6AhneIKAqVF1HTH4',
#                  '0SuLAslEMFZAXf0SwY7syi',
#                  '596auwbjLymQr3r7vSvNlx',
#                  '6gNeR8XudxHTHRgoCAsW8s',
#                  '0rAX31FT5w3ZQbQMUSkxy8',
#                  '333v4s9EybUEFOY6ComIC2',
#                  '2W8gwUI8uoj9RyKvfjWyOU',
#                  '54BLy0zSiBUOINjOwMC3M2',
#                  '661Ns9G25zHdih4qVshBO7',
#                  '43dS3iPBFSmO4ca3LfbkuW',
#                  '16FMLk0zDRc3qymkIJodlN',
#                  '4y7XertbNa3VkUS22J2Pav',
#                  '5DGKFUZ54VQ7EfXyx29Uuh',
#                  '5ndfVSDyPq90jaIUhNPeby',
#                  '5c0pfKibxcnwpdbjknapXq',
#                  '6pNyzuczjJVCUKgQOeg1Pd',
#                  '77BpytsTfXz6mgZOjCCRrB',
#                  '1C1gmhJX3FJPUYC1g6Dima',
#                  '1yV7ruaSb6dF02tS2sdWhR',
#                  '5aGhtbviqUqjtno5vcUmCN',
#                  '2YgAAAq8h7nPIMVLVVSHtK',
#                  '5fzsYCIHqSqEnmoY16zNc5',
#                  '3erAiWBiKsbVG39cqCrsI0',
#                  '0L7urInJWJwBXrVeunHwCU',
#                  '4MaYM2GDRHv6NxxXLBYJwT',
#                  '1wdemDqMqYyIVLLcy3dlP5',
#                  '3Tj6TtU3E3dXo0QYlZFmCG',
#                  '4REz0vhUp3WbvlUecwSUOi',
#                  '44BxEH341a9zeJq2z1UDdc',
#                  '2iNXdaNx4cArMmjCg6i3A4',
#                  '0XBQo5SfE4nU3KdYdKBnnw',
#                  '1ZngdGEf8ECLCd1iYbc7mG',
#                  '06ND7qqsmIRCuWdQNQIlTE',
#                  '1TX4h6MrIZ0K3r4OOG11WO',
#                  '4PCyzOTAB7zfJaxaS1uLSY',
#                  '0aASUtDb1N96NJDwmWj5Gf',
#                  '3SWZg7Wr2s29jYPiOPa7TF',
#                  '6K2XjgwKiIFDmkqqxQRX1l',
#                  '1Sx7mzaumD7xXtW098UoPT',
#                  '7crT2ZbF4BZRb17EZ5IRkh',
#                  '3QJPXOImtATOO48YB5CgWa',
#                  '612YdfqCQMnEJDnsuj7o77',
#                  '0HVj61S4pQJdQhgZP61G65',
#                  '0fg8CqpjdojMyXLNzM2PaJ',
#                  '3ebXMykcMXOcLeJ9xZ17XH',
#                  '3EmmCZoqpWOTY1g2GBwJoR',
#                  '4aWmUDTfIPGksMNLV2rQP2',
#                  '4qq6wMwxWuiw7NKm4Zis2v',
#                  '2wAq6u7oN4dKK2RvTvo2iO',
#                  '4s2RFlqNEMJ6PngBUcJNOs',
#                  '3RLSfCjAJAeapkv7Q2T8VI',
#                  '1w3wkv5EPlYBHi7N21XADR',
#                  '12wiyBZqQ3mOU7AfygXJCw',
#                  '2vW83jTd5pMd1tW3OyvL8o',
#                  '5IY0mD3WPkpxs1RWxqXtkt',
#                  '1eL7OBYaXOt5wQZHDZc5va',
#                  '24zNM3CNsoW8hvm7ZNb74o',
#                  '3AEZUABDXNtecAOSC1qTfo',
#                  '1a5Yu5L18qNxVhXx38njON',
#                  '66qlqxhEMpSHOzjRK4il0b',
#                  '1QjC2KRzi0Nm3L4AAREwnY',
#                  '6Zo58fraaPpTUUdYHwH0sf',
#                  '6nq1UXqPzEPPIG54YMSnhn',
#                  '5FREy2bRo5ThmdMUzwHjsW',
#                  '1EQ8sBQ7Abv9DvNBzhXAcv',
#                  '6HhXiy5XZ81Pyv3yCZMtj1',
#                  '0g8L4DJyzH7CG0nPqGtNlR',
#                  '0oEweHsuQagFuqXct9UvBm',
#                  '2wk3rEvm71VGkUi7XBX3uT',
#                  '6kxwc5gVuazlFo178WoVbF',
#                  '39S482DCKS7mjNKr1xgoAT',
#                  '6rQSrBHf7HlZjtcMZ4S4bO',
#                  '43jBqV3j3Xi1g6wO0bhIMd',
#                  '56cswAa9WdFBsjsTyPBAKA',
#                  '0FE9t6xYkqWXU2ahLh6D8X',
#                  '19pqsnlv4Phe6xfw26EeRb',
#                  '0EPxmvsG1BY5td4aTOkWBF',
#                  '5zt6akE5uXBuVKSukP4pw8',
#                  '0J1TzQOuHyS7KA6Sq33flE',
#                  '3QhJAGDdxt749dFveYVy4M',
#                  '2wFnRPjuqwNySFiK0Qfg8L',
#                  '2CW04trIoYMbroZWDzPAjs',
#                  '0NDTPSJS73KJkCWEL4sALc',
#                  '2ZnuIK4LbnJMXWDxhXAuSg',
#                  '1cAQhLQAW235Kyy1Lnz3ZR',
#                  '7xpDGoUGbtaquk5xMvzwTh',
#                  '3wyElammb2nsBW3C9fAkIk',
#                  '0hB6dJTTZ5clDvphHmhFSl',
#                  '44H9P7SVM6o748bPrpdJOE',
#                  '7FqJY9Gb4slImivE35f0Es',
#                  '5PMOxYz7rfeXLEzJnTdcei',
#                  '5uu3JPIIjqRL6Z2Dvmq8qn',
#                  '2hxWfUcyttEpiMRkntMxvE',
#                  '7rrmHHc1kY9vkIZnXrcH7T',
#                  '5xpVvOlrjPMqsXIDeNkSux',
#                  '3IRFILKz22Ckti8cHiGsRD',
#                  '2PIHTeccvbpmrSeYrlWkfx',
#                  '0gRNBFAXFhq1Z8QgTd0aXI',
#                  '2UbbRqKrYBdfHanEjIZvPs',
#                  '1U5zdT78JN2K5PPJEgyoLG',
#                  '5XKUTawRWuTb8edaGn38gB',
#                  '4Fp23GGA5WNWgoDjdhBHeK',
#                  '51DpoBqyVZsVQCJ9g98nWt',
#                  '0NFVg74sSsdU1gNc9xfpIO',
#                  '2YNnsUUgc23G8Th8TKpH44',
#                  '3E9s5Feisg3xmzzAHdq4aa',
#                  '4aAq1afusFG6jRiOSHQZvN',
#                  '2Dp7t5wktH3hgI6mBcJ1y2',
#                  '3IU6xbfNZosvTdRrGs8b2u',
#                  '2dqds2LwLZmU4COyM54RkS',
#                  '5GhmKZ7uZUqf4W5g4aR5zK',
#                  '3N6bHq3vdwWacmUPIJV2tL',
#                  '2spLJ8KbU1MC2n81YeMOck',
#                  '0YveezON7jpiaHA8fnUHxN',
#                  '6fTdc7h98EoJPt2Mbkeat1',
#                  '00NAQYOP4AmWR549nnYJZu',
#                  '6b8Be6ljOzmkOmFslEb23P',
#                  '5vdp5UmvTsnMEMESIF2Ym7',
#                  '1AhDOtG9vPSOmsWgNW0BEY',
#                  '37F0uwRSrdzkBiuj0D5UHI',
#                  '2rizacJSyD9S1IQUxUxnsK',
#                  '5HR4CYT5nPpFy8m9wJQgrr',
#                  '4F7A0DXBrmUAkp32uenhZt',
#                  '5knuzwU65gJK7IF5yJsuaW',
#                  '3dhjNA0jGA8vHBQ1VdD6vV',
#                  '63MgFVcIldlw51imFtcgK1',
#                  '3txHZTpGeVASXa5ARwoRX6',
#                  '4gqxE2PMdk6HvZKEqsQ8YE',
#                  '6GoFm9E3Nkjve72dwOhmXj',
#                  '05J1lZO0xSNVKtAsQkQOYk',
#                  '7wpnz7hje4FbnjZuWQtJHP',
#                  '3u5JwV7UmDUgNkgJ4obkpt',
#                  '6xNGveFlwGGoyfiESSvsKs',
#                  '548YYxvWX4FslqAwI2HFo4',
#                  '1Tditr5KyzStSK3GiO6Xlj',
#                  '70irAGrMdoXxKzeG4uiduP',
#                  '59nm8mNBtNiGWZMgrhU7wx',
#                  '0XgIrW4bDmRqO5bzA3UeHS',
#                  '0bOqCHcUOMEDoDqYUL0PLW',
#                  '2TE9rkhJYDctxgzak0AnSb',
#                  '2GMUokyMDjYdVa0Qv7KgNz',
#                  '1p6dBmCdP7xh3OMTYJDZPK',
#                  '0YtD2P3M3d56pv0OkNpsHl',
#                  '4uZvMzLesJdtQ1ZJoMtdG7',
#                  '4JzAJ94FZ46g8ZrISUyK6X',
#                  '2tX9QwcHOwWx01QSbLuB71',
#                  '5CkCOlVxiYPzREq0PeCKAN',
#                  '24IMxi4RUakB4bleLn2uBE',
#                  '7tZ2ul7cQBdw7gePR7GhRB',
#                  '4goNqp6L6of6FoJ8gH4RBP',
#                  '6ccKu0LwJzOhLAxBwP2PTk',
#                  '1xFgXCY8Zvo76gHg4RgUaU',
#                  '2InJDvDcA4RXEeA9njdibl',
#                  '6aRvRhWAF2AYgDnNXEUOy3',
#                  '5LZQ5s0kRZS9nBSd1xLK7U',
#                  '6XwW7NBAf63vzAtLln067q',
#                  '4wFHfY9IILHLNwakPuFogD',
#                  '3fo6DYGktjENCiagUeU9yH',
#                  '42ydLwx4i5V49RXHOozJZq',
#                  '1WniHvhq9zTkny0WvGXX8o',
#                  '7aV2mflaASUmGhCErm7kBO',
#                  '6fujklziTHa8uoM5OQSfIo',
#                  '5MFzQMkrl1FOOng9tq6R9r',
#                  '3J46Z7HsVAe1Q3lVOwIIoZ',
#                  '4gvePWCd0GfkC40QshflUy',
#                  '0xn3H5i0su6w6PLFDqqSBz',
#                  '5sudtP2ME6aIHN20glKW0k',
#                  '0A9QtfjCu7ZZ9Aja6AXewN',
#                  '3TZGlc2usRMyMFQvDvE8m5',
#                  '1PyNl4pahbBD1ohhxfWyac',
#                  '0qRZ9ydGdzeVk3S01pLGoJ',
#                  '3QwBODjSEzelZyVjxPOHdq',
#                  '6bLopGnirdrilrpdVB6Um1',
#                  '7erByqCV1mcImSeCYh1XmW',
#                  '3t0h32ZYlUCXAn37IIIOaS',
#                  '3dO6fRY8FAMIs0UMvt0ghH',
#                  '5wvYib82q05wiNjLElD8GJ',
#                  '0iXkmLTj8nMEj2kjqm3YbF',
#                  '4UD5KGTHwkdrvMOuPUwzNm',
#                  '168P6e9mrfugeE9nKhEE8C',
#                  '6TjP1C3sGQH1jBfzUXfcMg',
#                  '0mmwLJwH5oqcL0iaEl4lUT',
#                  '3sz8Gn0fOmXmyXOaPSWBJ9',
#                  '5PU9P83o25vVakg3gs2pxG',
#                  '006pMMCuRo2TFjh8sNGSov',
#                  '3yI282DoIJyERd0vGukMoB',
#                  '6wky1KFF0YvgtrFaH4ep9r',
#                  '2kgT6sMwXd3mdeXhBbLMQe',
#                  '0PgsB53yhlKs8D19LgYU4i',
#                  '5ZjXLQ1d2BLQo0OTbR5kTv',
#                  '5rhijzoJmc7ZdnEgBS58Wh',
#                  '5Du6gEDduLCB9FIm9xIE4w',
#                  '1TfqLAPs4K3s2rJMoCokcS',
#                  '2miAut6dp9BWdGmOxwSGEC',
#                  '1AqfIfEQyEaME7fiv3HzyU',
#                  '7E1duSMvHGUcYRgwrMZOUf',
#                  '18Lb0yf7HlgETLgfaBG6eV',
#                  '31svfXMDnt8sgu4SuDqL2K',
#                  '2BuaFGE4mY8HR8FBLoOE1Z',
#                  '2TybUDN7KV3er4j2rqfbVu',
#                  '0pK7xotcYmRlwnJQUTwi17',
#                  '0cOad1EbVLwi06mHIcqGip',
#                  '5TL6dxDpmHJRr302Q6Qaup',
#                  '5iPoYP37zMofM4GSC6VSDu',
#                  '79nopNMm3rJSUfQfMkG0Ur',
#                  '6Za6hbqmYXwH9DCJQcRJv7',
#                  '3rUEaYVs7O66ye34bhYSBR',
#                  '2aeq2NA5dOlcjccHWjYD3Z',
#                  '7EiZI6JVHllARrX9PUvAdX',
#                  '3vv9phIu6Y1vX3jcqaGz5Z',
#                  '7xrA11O07xo57Bbg6p4hck',
#                  '4sQMalN597HdggTu196aL0',
#                  '4dASQiO1Eoo3RJvt74FtXB',
#                  '3GBlLqIYgB8zWaeWDNJzdh',
#                  '6YZdkObH88npeKrrkb8Ggf',
#                  '4AOpEhqA7zHxQjkHmRrAp7',
#                  '5OOkp4U9P9oL23maHFHL1h',
#                  '1Tt4sE4pXi57mTD1GCzsqm',
#                  '0gb1J5UrTpzaU1s3nupgCd',
#                  '2CPqh63wRVscbceKcPxwvv',
#                  '1CUVN2kn7mW5FjkqXTR2W1',
#                  '7yHEDfrJNd0zWOfXwydNH0',
#                  '6i0V12jOa3mr6uu4WYhUBr',
#                  '6JV2JOEocMgcZxYSZelKcc',
#                  '53B2XmmjJ9rriW1qciMBeX',
#                  '6DNtNfH8hXkqOX1sjqmI7p',
#                  '66Cipjt48FUYGrdNSRfkIC',
#                  '1iOGTda6diEPASEO34pUNx',
#                  '5hsDGWNJySHW1XiLBXGw7b',
#                  '5p9gLteSKlviEIeiFizUxd',
#                  '6VmrEVDPnTmFuUaqyVI60N',
#                  '3qf8UieeXpBnLfghOjDHkF',
#                  '0WOg0OZwO9aRKjXrMGVpLb',
#                  '6wb0ot3hSAm1iXA5I4r252',
#                  '0tmNq0XcjZbj0uSnPJRvXc',
#                  '3BJQguEE2SH9NnYZrTQl8V',
#                  '6RI3cBgzqhm2TTWccZlIuW',
#                  '3YIrFBKlypS2LWl0MSWpD7',
#                  '0vFdGuIRXfgQRVcdcmW6gp',
#                  '2S9UqunCrQ18g4uGMkVtBA',
#                  '6ozPdYe5t1YsEWlTr9otOp',
#                  '4N3w7oEnr7XtO4ccxkPZas',
#                  '1dNFc3QDgoNkP4azpYFfuu',
#                  '33ieEYWWbycPDdHemFZ94o',
#                  '139VPl3EKaYkB35KC3XXwM',
#                  '1AMW4fl99BXHL6HXv9ajuo',
#                  '19saAGa1EGi2OQwRdYBYI6',
#                  '2hCyvnRXrt3HF775oJuFta',
#                  '4RzgWcVsI3QfwZgZjZhZ1z',
#                  '0x7kv3HIsgKfL6EgcOGVbE',
#                  '4kf25WJI0BrGkAzMCQKdM4',
#                  '1DtMRYnTaLxKASua0QITjQ',
#                  '23epAZAytNRPvpcFDUxll0',
#                  '3pd2dfAEc0yvxVVfkgnpec',
#                  '0UgNzhymAxUJD51nsiDZHf',
#                  '1i43NoFGtLDqsDn9ti5P85',
#                  '1o47ACCZud6LNpl7ojb5GM',
#                  '3aMfoKhyq3M2yXbD33gv5q',
#                  '5QtswlcoTZAysUDdmv843Y',
#                  '7hqba4Inmu3vDyAGcMXdIk',
#                  '2SYnUqZocEO2gvVxrwyN5V',
#                  '0Ct2urZf4Ufmx6D8J2JBOJ',
#                  '2SUpC3UgKwLVOS2FtZif9N',
#                  '1zbTIdIbLYlXjtOqlHALh4',
#                  '72ZxxtVWKGiICLhyL2Fcix',
#                  '77VvA3wNFxm1P9amCKlVHQ',
#                  '41CqhTwCbwwwZ0SOjL4HBc',
#                  '681JQwws44wzHJg8uRE9vv',
#                  '05yUPwdzRUURI1uzSRFRTy',
#                  '4EupaZnUh9CBOTisAoGesq',
#                  '6adoWes3WGC4SlcMXIeJvY',
#                  '52zDFiKlCOGaiBbuhPkZue',
#                  '2TNN6kDVMNCP5ysuXZM2tD',
#                  '4t4oqMSwwmpHzQIu1aok1z',
#                  '5dSFlPDHjAuYU1apyrRgqV',
#                  '4xl9cBtUGiK0e9aX18ojke',
#                  '1bJkgQa2xizfvBeF871jhz',
#                  '6AadQMbZNCwaGyPCUKyTec',
#                  '5qsKdwDWbhNTygUO4mGpix',
#                  '3qxQXmwp6WJ7nlJJZpl1Qi',
#                  '2bhClfvMI1WBazskedPFB5',
#                  '1UbqS1I358tyD3Dz6sEJ4P',
#                  '4SCH5CuivFcShLpTg8lYOf',
#                  '4ImIJRZNJhNQLLdUFSYJoS',
#                  '0LIU3eOAwXCZlWOiHuItkj',
#                  '3usdTkRcpEDV27vpSUkvg6',
#                  '7DRP2VOMpy1rrk3iYFLCW9',
#                  '0cdzCblUzNVtmvZ23aqHOf',
#                  '1dUiu9sLlbIzzWki04oMYa',
#                  '0aMahQepTIKgwFYT7jJTm8',
#                  '4rzQR9xxaXHYcyFeoRBhuc',
#                  '1fGdcVXLvNDDxGyZeSxCpV',
#                  '3yXmslBa2eTtFI2tSXphR1',
#                  '4FLkdTiZXMJqenotH0M5FP',
#                  '0rCuRc07y6l1kPYj0JSRg5',
#                  '7MsfgQIzqsesbjEG9WrpV6',
#                  '3IJiRftxd6tEczyfAacHP4',
#                  '1wyclICZwhqZYizAdtvzYu',
#                  '1xFtF3Zo6d7CJQfcgsPbQZ',
#                  '1mPRBPKwtwyJo00rPu73hk',
#                  '6G7AKFhDJRsJIeBkJNHCVi',
#                  '3lgi5uRAPNMLM2waUQkzY7',
#                  '28AnQ0p98RFzNGcVqjd3gU',
#                  '1itgbGVeyfCBgHRATp1TF5',
#                  '2vItsWbkB6DoEhGawmv2ag',
#                  '0kgjBH2VXOASDFb3WDN1Pg',
#                  '7ad8Dl0dVmj6i3hfRxUKoD',
#                  '7cnm6MnAwwnf52Jy47WTGN',
#                  '6RB9YvNyP0RZfCUcMtZELH',
#                  '5Yl8hDh0Lmtg0cURldz1lk',
#                  '36dFvc2hC9onvllcX7jeGF',
#                  '4TiCMkortGCNpp0HJAWvq5',
#                  '36lO0n3hzVK9zJONfSdmKC',
#                  '0SVlY9SijcJYDXbcUwlbTI',
#                  '2XpNiWkjrZWfhUBiJvV0BX',
#                  '1vXLFBaaptpTF7pVgdsdAu',
#                  '49gYGGgPYCzMRJEw7ZrvHm',
#                  '3jDdpx9PMlfMBS5tOBHFm9',
#                  '5SVCh0OYgZsnyhiKGU1V1C',
#                  '3bqzUDyN8wTCmdyzg6OlF3',
#                  '63bP2ISJjw7FkGll83gfmJ',
#                  '6s4sFuYRgBNg2jOD983ApY',
#                  '7xhOm9p7kYZpGgMKJNQY0v',
#                  '0P3k6Jipqv1UWX0a4GmUuj',
#                  '0gNxi721t2RcPt5LdWGfpb',
#                  '2gywMK0AQvj8QZJFcEO4R3',
#                  '1OtZIaJBXo3Pe6nfaMsjKT',
#                  '5LRlWrPlbiWgJGiz5xp4I9',
#                  '56WkfBKWfbvauMgeK8nivR',
#                  '4VTWFjy7CKvH23wtvfNdQg',
#                  '0e4tQbb6dwQRmMe8IeZHhj',
#                  '1F4BES9lxRMi81sfeqvKPJ',
#                  '1VLKbAQkcRcqnKC2Todf9J',
#                  '70pLjDx7rTSSMv47icvNvb',
#                  '1ict4ztb5fkIQJPXm5qzvW',
#                  '7Ha01hP3FQk1CdICT3W1m3',
#                  '0PJIbOdMs3bd5AT8liULMQ',
#                  '7KOcjfiSuMPsQqLXhD0PlN',
#                  '5SqSckut3FcoQKmGkMWgp1',
#                  '7kUtJKGZzLNgIkq1Galkt0',
#                  '0rHVd8h0cFwgLgPFem6S60',
#                  '2Z8WuEywRWYTKe1NybPQEW',
#                  '12VWzyPDBCc8fqeWCAfNwR',
#                  '7uSZPbd8DxdkmSauCKnITY',
#                  '3e8JYpIzeLB6qOkyLm0GLJ',
#                  '2L2RFryALV76T2VohVEVeX',
#                  '4wQ8cM5towhQKEOt5G9u0j',
#                  '4jZReBOx8CdXg5ZOFbhH28',
#                  '01iyCAUm8EvOFqVWYJ3dVX',
#                  '40riOy7x9W7GXjyGp4pjAv',
#                  '5cP52DlDN9yryuZVQDg3iq',
#                  '0aJzrpwqEdGZQsSHLvbbpz',
#                  '74QCZPlpayjvQ4yJJFljfQ',
#                  '2Fn3coxd0xAZ09JtrgcgHa',
#                  '5ZEM9j0jrFr5RdHEbl2MYV',
#                  '40YcuQysJ0KlGQTeGUosTC',
#                  '0azC730Exh71aQlOt9Zj3y',
#                  '7AsFFiQEozWPh4BiHTTwkN',
#                  '6XOsXDAtgNGOPzyalU4zcT',
#                  '4Te7on8VPDIbORBNh141sC',
#                  '3tS8q8SXxtrYSN8UgeQt6q',
#                  '1OOtq8tRnDM8kG2gqUPjAj',
#                  '5ChkMS8OtdzJeqyybCc9R5',
#                  '3au2vSIdhu3JDzGiffhZds',
#                  '10PL0ZRbnuLRFfhkj8lNFV',
#                  '56EFkxnjX35BOaoY9k0zK3',
#                  '3mTUqLbtWm2DAEwvQTyu4d',
#                  '7IDbfk1mC7B0Hyozn799yv',
#                  '1zvLMu2LaeAX1OUgJlfXFc',
#                  '41ZXQFAywncRjnDvtTMYPw',
#                  '1CGLurVTmoqp8fJoOTKWJ0',
#                  '79tl45OGogfoucy9GDohG2',
#                  '3ZrWmt3DGH75hItHp6uWLz',
#                  '0bLavFKcMljHzTJAx3sHNS',
#                  '34TOZVEDoy6C66oCKArIIm',
#                  '33DyeA0oUHmK4lpUa2RWCv',
#                  '4aFv0v8fpRsC2hFaIZEYGU',
#                  '5QbG8DHwM08icWs4EEq4U3',
#                  '5mmfVd0xxbtKrpfQrlwuQO',
#                  '6lEFnrBFECY047g1hCupsk',
#                  '47CHnEjuOG5GMwubAGCSAp',
#                  '6OmKF6WW3eQtZzGQ4hDSOX',
#                  '2mXbqtqKuOX9pyyUga7UZ1',
#                  '4slY2RUgG5c3Tyb0bNI4bE',
#                  '62osYzM4qkpo2S7CdpsMFs',
#                  '0j2qUNSW3dbSRjRMUORR3T',
#                  '2fzly0v7ndY7NydVFBE2E0',
#                  '6MFjlcZxDTAtdkjbFiw3zq',
#                  '7KznRR056fzQZyo0PHZlh6',
#                  '5p6me2mwQrGfH30eExHn6v',
#                  '4jTiyLlOJVJj3mCr7yfPQD',
#                  '2hQCzcb3qyZirWzOD5Yzoj',
#                  '68iIALIAQ03juj9BZpafox',
#                  '6dpI0HKnzfBN07gFdD5wWf',
#                  '5kZRoc6Gz7u5eu4a0YM2LS',
#                  '6n7rJUcwmQDestMYXoSoZF',
#                  '57wbOuofBE6Cb3mMPuQ24i',
#                  '3SQohmQQr9xi63xKsrQRK1',
#                  '0JQNPHwYpYRUWnjDI4Bow3',
#                  '0k93MXOj0kSXo84SvSDeUz',
#                  '01GzjMM0wtLAHaKTfvpUv7',
#                  '0qMGwkWvYN3sYNkT7B9wVt',
#                  '7bFOkwjxOcGaw6ZULE58Mh',
#                  '71EnloViXmSKrQkrkaYFxF',
#                  '6WLS56xiRrXjSm9RSdL3zD',
#                  '27SdWb2rFzO6GWiYDBTD9j',
#                  '14WWzenpaEgQZlqPq2nk4v',
#                  '7vfWgVGiLgnGbInU5lvSQg',
#                  '1PYeX2IAYleaPGd0Pc7ZOT',
#                  '3lxbVaqdWOIIUCgU4sUNJ0',
#                  '2W1tq1VRmGNTdUl1yKbcIm',
#                  '5aJhuze13LOoLthmiG8YIA',
#                  '0W6yJKJW8I04iDT6BsINaL',
#                  '6TaqooOXAEcijL6G1AWS2K',
#                  '1i1fxkWeaMmKEB4T7zqbzK',
#                  '3RiPr603aXAoi4GHyXx0uy',
#                  '0WEVf4RhIrcr3S3ULBrt0T',
#                  '42ftjU4cTN5UTRksyqBKZJ',
#                  '53Y0kdCa1CZ9gRqEuknfwy',
#                  '34vuwpTj9M0cFYJ0DeK97Z',
#                  '73qbHEi2infwn7MFXneeDq',
#                  '5MTqczrMNkxZbFghiopgHL',
#                  '2KjpWqvSKoQh0XIAywplWn',
#                  '2fouwOFRsS5LmrCJVLe40X',
#                  '19QGIdhhRCB303eGVUQyZM',
#                  '5cxp9kjCFyJwzv3lzeX7ku',
#                  '0jY829pCMnstlNtaE72vSB',
#                  '42ZVk59gT4tMlrZmd8Ijxf',
#                  '6RJdYpFQwLyNfDc5FbjkgV',
#                  '7mMaJKkvMKUB4KPtWjMQ8D',
#                  '7D6F9245DyUX1tZw54A97j',
#                  '7nZBNthuHTNQJZ76CUp9nD',
#                  '43Ei9NSyEjgFYXoKLISyz4',
#                  '5T8t1yJwAf6Dr6fIFGPjro',
#                  '3jEPu6FD1icy9cLllhB2XK',
#                  '31eL3t4POZ9Cc6YwpB5GTS',
#                  '0VffaI2jwQknRrxpECYHsF',
#                  '7vqUr6K2Js9Paq4kdNSOm6',
#                  '7G9yFIOa2qrc6KBN9AtNnd',
#                  '6Knv6wdA0luoMUuuoYi2i1',
#                  '0PT7nlpo11hYYyfnBgtilT',
#                  '1vFVOr0psCHVWjjK2Jp298',
#                  '4HPdvi8pV1lB2W85GhVIf1',
#                  '4ngziMHuT4q6DesywTER3G',
#                  '7AdKHBV1LRnHoIXd0fROEc',
#                  '3XGQozFBdNhj2irmqEduFG',
#                  '3V7kPWULwqwhnGWjL4nBRz',
#                  '6O6NWaYqB6HrWtDLoEQYZE',
#                  '5z5fbPGBqaT9ByN55TnRMT',
#                  '24ea4ckKJHeqG39oavAw1n',
#                  '6sxqSN9YxAHzMzJ8u835J5',
#                  '4lvoo7y0UL6Snm8X4AtyTs',
#                  '1qbFBC9dzIoZBPaVxqsN8c',
#                  '3X7UE1ZHMLOzEvPHcWlrqr',
#                  '4xB8ED2Xb3CYLTEGLKtOju',
#                  '43n1gjvFikEQ1WhtoNDHpI',
#                  '0mQC7f117Nb9DPz7Y6RELJ',
#                  '51TG9W3y9qyO8BY5RXKgnZ',
#                  '5nNmj1cLH3r4aA4XDJ2bgY',
#                  '4pbJqGIASGPr0ZpGpnWkDn',
#                  '5T8EDUDqKcs6OSOwEsfqG7',
#                  '1TDk2Jmi4dVZhm2dum3Jim',
#                  '3YuaBvuZqcwN3CEAyyoaei',
#                  '2uDwRgwGPjXq0oj0hNCuFc',
#                  '7r9ZTgy31yObGZE6ZYDlQg',
#                  '7990Xs9HQx7FXVIDVPEwj9',
#                  '1NnRmjjzaPQm9vbaQ3rST8',
#                  '2jmJZpdJhCXhfEhewqui5G',
#                  '7wPXn0y3HWTYjJph5raP9b',
#                  '3lnbe8TB3lKxqNsikv8r6x',
#                  '5oNdTrafZ0joNCikz1Vdjd',
#                  '3CRDbSIZ4r5MsZ0YwxuEkn',
#                  '69bp2EbF7Q2rqc5N3ylezZ',
#                  '7Jzsc04YpkRwB1zeyM39wE',
#                  '0S7zL7ae0KpOSPKeFQpHo8',
#                  '0KZPUqtITLhmZVH4Lx8qT8',
#                  '2HHtWyy5CgaQbC7XSoOb0e',
#                  '2QOMGq8wVTZbLmh7McrvgF',
#                  '6HNruFQlzQx4ulL4ppRLYI',
#                  '3GfOAdcoc3X5GPiiXmpBjK',
#                  '3lUmaVqVvSGXahObJ85qWc',
#                  '6Jao8qdCB3VYG4PhPzCEIm',
#                  '0Kd6H9yzcKtDuLHgHEoYYS',
#                  '0tZ3mElWcr74OOhKEiNz1x',
#                  '59WN2psjkt1tyaxjspN8fp',
#                  '63OFKbMaZSDZ4wtesuuq6f',
#                  '3YBZIN3rekqsKxbJc9FZko',
#                  '3AVZaAbDvR6rs2NN4n0aAF',
#                  '0GuQcX8wTe8bUZ72ZncR7m',
#                  '6EiHcFupatDGdEGq1XzDAx',
#                  '4WxC9MO5FYUFhPrvqtZOlz',
#                  '6splO3UF8hSmK33y5fJTNk',
#                  '1brwdYwjltrJo7WHpIvbYt',
#                  '1wYZZtamWTQAoj8B812uKQ',
#                  '6lDo13SSgTv0WbyUQKgnjk',
#                  '7gBj0VgcuAgkXkiRRYvSmK',
#                  '69uxyAqqPIsUyTO8txoP2M',
#                  '2DrEeo4eMULdAVe1U7P9PB',
#                  '5V3mdRI2yQxbSsJGDPc5lD',
#                  '1Qdnvn4XlmZANCVy3XjrQo',
#                  '57J2znxukXsXzS3XPuZ1TG',
#                  '1VNWaY3uNfoeWqb5U8x2QX',
#                  '6rUp7v3l8yC4TKxAAR5Bmx',
#                  '2p9q7lIzhJygg323PqeMbD',
#                  '1CRESO4AuKm5B5Lqodk7t9',
#                  '66WcaWVGRFmpx0euxmw9yM',
#                  '0E1RL6rKe18aUq70B2fgXs',
#                  '6nmz4imkDcmtwMjocAzFSx',
#                  '5OQsiBsky2k2kDKy2bX2eT',
#                  '5FZxsHWIvUsmSK1IAvm2pp',
#                  '5UWwZ5lm5PKu6eKsHAGxOk',
#                  '5Xak5fmy089t0FYmh3VJiY',
#                  '6QewNVIDKdSl8Y3ycuHIei',
#                  '1L94M3KIu7QluZe63g64rv',
#                  '6Zjs6nPrDHmKvAUw80FJH6',
#                  '2VMxUaruqkrEVRzCUgmrUy',
#                  '48n7IBeWDH1rAvk7ZZWTKI',
#                  '7tMS60qyTwG43P51pmr8gI',
#                  '0a5iI5LcwLlz8DLiSy8CN1',
#                  '5CMtWJRI0MIlpJC3b3WmNj',
#                  '4jacsL77ZYnpInmTtUBaJW',
#                  '3zkWCteF82vJwv0hRLba76',
#                  '7nemcVsXVFZF01iqpIIo2Y',
#                  '7LRMbd3LEoV5wZJvXT1Lwb',
#                  '6yl8Es1tCYD9WdSkeVLFw4',
#                  '2zYzyRzz6pRmhPzyfMEC8s',
#                  '08mG3Y1vljYA6bvDt4Wqkj',
#                  '57bgtoPSgt236HzfBOd8kj']}]
# []
# []
